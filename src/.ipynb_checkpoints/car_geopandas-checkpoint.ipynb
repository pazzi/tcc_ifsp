# %%
import matplotlib.pyplot as plt
import geopandas

path = '../data/teste_geo'
df = geopandas.read_file(path)
path2 = '../data/veg_nativa.geojson'
df2 = geopandas.read_file(path2)

# %%
df.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 736 entries, 0 to 735
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   COD_IMOVEL  736 non-null    object
#  1   NUM_AREA    736 non-null    float64
#  2   COD_ESTADO  736 non-null    object
#  3   NOM_MUNICI  736 non-null    object
#  4   NUM_MODULO  736 non-null    float64
#  5   TIPO_IMOVE  736 non-null    object
#  6   SITUACAO    736 non-null    object
#  7   CONDICAO_I  736 non-null    object
#  8   geometry    736 non-null    geometry
# dtypes: float64(2), geometry(1), object(6)
# memory usage: 51.9+ KB

# %%
df2.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 1554 entries, 0 to 1553
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   IDF       1554 non-null   int64
#  1   NOM_TEMA  1554 non-null   object
#  2   NUM_AREA  1554 non-null   float64
#  3   geometry  1554 non-null   geometry
# dtypes: float64(1), geometry(1), int64(1), object(1)
# memory usage: 48.7+ KB

# %%
df.plot(figsize=(30,15))
# Out:
# <AxesSubplot:>

# %%
df2.plot(figsize=(30,15))
# Out:
# <AxesSubplot:>

# %%
df['NUM_AREA'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
df.plot(column='NUM_AREA', cmap='OrRd', edgecolor='k', legend=True, figsize=(30,15))
# Out:
# <AxesSubplot:>

# %%
df2
# Out:
#           IDF                            NOM_TEMA  NUM_AREA  \
# 0      389831  Remanescente de Vegeta̤̣o Nativa  0.664570
# 1      389831  Remanescente de Vegeta̤̣o Nativa  1.416174
# 2      391185  Remanescente de Vegeta̤̣o Nativa  0.042758
# 3      403777  Remanescente de Vegeta̤̣o Nativa  0.107874
# 4      403777  Remanescente de Vegeta̤̣o Nativa  0.561417
# ...       ...                                 ...       ...
# 1549  9907555  Remanescente de Vegeta̤̣o Nativa  1.012527
# 1550  9907555  Remanescente de Vegeta̤̣o Nativa  3.234759
# 1551  9907555  Remanescente de Vegeta̤̣o Nativa  2.229738
# 1552  9907555  Remanescente de Vegeta̤̣o Nativa  0.000013
# 1553  9934197  Remanescente de Vegeta̤̣o Nativa  1.114380
#
#                                                geometry
# 0     MULTIPOLYGON (((-47.51794 -23.01578, -47.51858...
# 1     MULTIPOLYGON (((-47.51635 -23.01382, -47.51643...
# 2     MULTIPOLYGON (((-47.52084 -23.00003, -47.52078...
# ...

# %%
df2.plot(column='NUM_AREA', cmap='OrRd', edgecolor='k', legend=True,figsize=(30,15))
# Out:
# <AxesSubplot:>

# %%
soma=0
soma2=0
soma3=0
soma4=0
soma5=0
for a in df['NUM_AREA']:
    if a <= 40:
        soma+=1
    if (a > 40) & (a <= 150):
        soma2+=1
    if (a > 150): 
        soma3+=1
    #if (a > 1000) & (a <= 3000):
    #    soma4+=1
    #if (a > 3000):
    #    soma5+=1
print(soma, soma2, soma3)
# Out:
# 597 115 24

# %%
df.groupby('NUM_AREA').count()
# Out:
#              COD_IMOVEL  COD_ESTADO  NOM_MUNICI  NUM_MODULO  TIPO_IMOVE  \
# NUM_AREA
# 0.155544              1           1           1           1           1
# 0.350903              1           1           1           1           1
# 0.470027              1           1           1           1           1
# 0.723185              1           1           1           1           1
# 0.849344              1           1           1           1           1
# ...                 ...         ...         ...         ...         ...
# 995.054382            1           1           1           1           1
# 1116.098600           1           1           1           1           1
# 1118.525146           1           1           1           1           1
# 1487.227500           1           1           1           1           1
# 3973.456299           1           1           1           1           1
#
#              SITUACAO  CONDICAO_I  geometry
# NUM_AREA
# ...
